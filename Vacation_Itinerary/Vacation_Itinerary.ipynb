# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# %load_ext autoreload
# %autoreload
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.

vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(20)
# Out:
#     City_ID           City Country  Max Temp Current Description      Lat  \
# 0         3         Matara      LK     82.20    scattered clouds   5.9485
# 1         7  San Cristobal      VE     78.80                 fog   7.7669
# 2         8      Sinnamary      GF     77.86     overcast clouds   5.3833
# 3        18          Kapaa      US     78.80          few clouds  22.0752
# 4        19   Puerto Ayora      EC     75.60     overcast clouds  -0.7393
# 5        22        Rikitea      PF     78.71     overcast clouds -23.1203
# 6        23      Hithadhoo      MV     83.10    scattered clouds  -0.6000
# 7        25       Kirakira      SB     81.68     overcast clouds -10.4544
# 8        27      Samarinda      ID     87.48     overcast clouds  -0.5000
# 9        28     Hambantota      LK     80.60          few clouds   6.1241
# 10       33          Basco      PH     76.33       broken clouds  20.4487
# 11       34     Porto Novo      BJ     80.60    scattered clouds   6.4965
# 12       35         Madang      PG     85.26     overcast clouds  -5.2246
# 13       38         Harper      LR     79.93          light rain   4.3750
# 14       39        Kodinar      IN     87.49     overcast clouds  20.7903
# 15       41      Bathsheba      BB     78.80          few clouds  13.2167
# 16       42      Mount Isa      AU     86.00           clear sky -20.7333
# 17       43     Blackwater      AU     80.89           clear sky -23.5833
# 18       48       Tevaitoa      PF     79.48     overcast clouds -16.7833
# 19       54         Acarau      BR     77.92     overcast clouds  -2.8856
#
#          Lng                                 Hotel Name
# 0    80.5353                     Amaloh Boutique Resort
# 1   -72.2250                       Posada Villaven C.A.
# 2   -52.9500             ALETHEIA Appartement Sinnamary
# 3  -159.3190     Sheraton Kauai Resort at Coconut Beach
# 4   -90.3518                  Finch Bay Galapagos Hotel
# 5  -134.9692                             Pension Maro'i
# 6    73.0833                          Scoop Guest House
# 7   161.9205                               SanBiz Lodge
# 8   117.1500  Aston Samarinda Hotel & Convention Center
# 9    81.1185                                Bungalow 63
# 10  121.9702                          Nathaniel's Lodge
# 11    2.6036                    Tour Eiffel Hotel Benin
# 12  145.7966                          Comfort Inn Hotel
# 13   -7.7169                                Screensaver
# 14   70.7031                    residency of N.B vadhel
# 15  -59.5167                             Atlantis Hotel
# 16  139.5000                  ibis Styles Mt Isa Verona
# 17  148.8833                       Blackwater Motor Inn
# 18 -151.5000                        Hôtel Raiatea Lodge
# 19  -40.1200                           castelo pizzaria

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.

info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
 # Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Piacabucu"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Piacabucu"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Salinopolis"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Tutoia"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Acarau"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start =vacation_start["Lat"].to_numpy()[0],vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0],vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0],vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0],vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0],vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
direction_layer = gmaps.directions_layer(start,end, waypoints=[stop1, stop2, stop3],travel_mode='DRIVING')
fig.add_layer(direction_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp Current Description      Lat  \
# 0      145    Piacabucu      BR     77.29    scattered clouds -10.4056
# 1      109  Salinopolis      BR     78.71       moderate rain  -0.6136
# 2      483       Tutoia      BR     77.85     overcast clouds  -2.7619
# 3       54       Acarau      BR     77.92     overcast clouds  -2.8856
#
#        Lng                          Hotel Name
# 0 -36.4344                      Piaçabuçu News
# 1 -47.3561  Salinas Park Resort Maçarico AP101
# 2 -42.2744                     Pousada Guará's
# 3 -40.1200                    castelo pizzaria

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
</dl>
"""
# 10a Get the data from each row and add it to the formatting template and store the data in a list.
itinerary_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
marker_layer=gmaps.marker_layer(locations, info_box_content=itinerary_info)

# 11b. Display the figure
fig=gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
