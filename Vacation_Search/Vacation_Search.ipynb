# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# %load_ext autoreload
# %autoreload

# Dependencies and Setup
import pandas as pd
import requests
import gmaps
# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)
#print (g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../weather_data/WeatherPy_database.csv")
city_data_df.head(15)
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0         Sayyan  15.1718   44.3244     57.25        51          11
# 1         1         Seddon -37.8068  144.8916     64.00        63          90
# 2         2       Hermanus -34.4187   19.2345     63.00        81         100
# 3         3         Matara   5.9485   80.5353     82.20        77          34
# 4         4      Sanchursk  56.9413   47.2499     37.83        96         100
# 5         5         Torbay  47.6666  -52.7314     37.99        93          75
# 6         6     Rio Grande -32.0350  -52.0986     63.00        95         100
# 7         7  San Cristobal   7.7669  -72.2250     78.80        89          40
# 8         8      Sinnamary   5.3833  -52.9500     77.86        87         100
# 9         9       Phalombe -15.8064   35.6507     61.20        88          88
# 10       10          Roald  62.5833    6.1333     35.60        93          90
# 11       11          Yumen  40.2833   97.2000     58.73        18          38
# 12       12      Cape Town -33.9258   18.4232     60.01        82           0
# 13       13           Roma  43.2128  -75.4557     53.60        50           1
# 14       14       Tomatlan  19.9333 -105.2500     72.43        78         100
#
#     Wind Speed Country Current Description
# 0         1.63      YE          few clouds
# 1         9.22      AU     overcast clouds
# 2         3.00      ZA     overcast clouds
# 3         3.04      LK    scattered clouds
# 4         8.16      RU       moderate rain
# 5        18.41      CA       broken clouds
# 6         8.28      BR          light rain
# 7         2.30      VE                 fog
# 8        10.67      GF     overcast clouds
# 9         1.77      MW     overcast clouds
# 10        4.61      NO     overcast clouds
# 11        7.67      CN    scattered clouds
# 12        3.44      ZA           clear sky
# 13        4.65      US           clear sky
# 14        0.67      MX     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria.
#Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
city_data_df["Max Temp"]
preferred_cities_df.head(10)
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3         3         Matara   5.9485   80.5353     82.20        77          34
# 7         7  San Cristobal   7.7669  -72.2250     78.80        89          40
# 8         8      Sinnamary   5.3833  -52.9500     77.86        87         100
# 18       18          Kapaa  22.0752 -159.3190     78.80        65          20
# 19       19   Puerto Ayora  -0.7393  -90.3518     75.60        88          89
# 22       22        Rikitea -23.1203 -134.9692     78.71        76         100
# 23       23      Hithadhoo  -0.6000   73.0833     83.10        67          26
# 25       25       Kirakira -10.4544  161.9205     81.68        78          99
# 27       27      Samarinda  -0.5000  117.1500     87.48        64          99
# 28       28     Hambantota   6.1241   81.1185     80.60        94          20
#
#     Wind Speed Country Current Description
# 3         3.04      LK    scattered clouds
# 7         2.30      VE                 fog
# 8        10.67      GF     overcast clouds
# 18       14.97      US          few clouds
# 19        6.08      EC     overcast clouds
# 22       13.06      PF     overcast clouds
# 23        5.32      MV    scattered clouds
# 25        1.23      SB     overcast clouds
# 27        4.16      ID     overcast clouds
# 28        2.30      LK          few clouds

# %%
preferred_cities_df.count()
# Out:
# City_ID                208
# City                   208
# Lat                    208
# Lng                    208
# Max Temp               208
# Humidity               208
# Cloudiness             208
# Wind Speed             208
# Country                208
# Current Description    208
# dtype: int64

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Country                0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df=preferred_cities_df.dropna()
clean_df.head(20)
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3         3         Matara   5.9485   80.5353     82.20        77          34
# 7         7  San Cristobal   7.7669  -72.2250     78.80        89          40
# 8         8      Sinnamary   5.3833  -52.9500     77.86        87         100
# 18       18          Kapaa  22.0752 -159.3190     78.80        65          20
# 19       19   Puerto Ayora  -0.7393  -90.3518     75.60        88          89
# 22       22        Rikitea -23.1203 -134.9692     78.71        76         100
# 23       23      Hithadhoo  -0.6000   73.0833     83.10        67          26
# 25       25       Kirakira -10.4544  161.9205     81.68        78          99
# 27       27      Samarinda  -0.5000  117.1500     87.48        64          99
# 28       28     Hambantota   6.1241   81.1185     80.60        94          20
# 33       33          Basco  20.4487  121.9702     76.33        70          56
# 34       34     Porto Novo   6.4965    2.6036     80.60        89          40
# 35       35         Madang  -5.2246  145.7966     85.26        63          91
# 37       37          Kidal  18.4411    1.4078     82.63         8           1
# 38       38         Harper   4.3750   -7.7169     79.93        85         100
# 39       39        Kodinar  20.7903   70.7031     87.49        44          94
# 41       41      Bathsheba  13.2167  -59.5167     78.80        61          20
# 42       42      Mount Isa -20.7333  139.5000     86.00        32           7
# 43       43     Blackwater -23.5833  148.8833     80.89        28           0
# 48       48       Tevaitoa -16.7833 -151.5000     79.48        71          91
#
#     Wind Speed Country Current Description
# 3         3.04      LK    scattered clouds
# 7         2.30      VE                 fog
# 8        10.67      GF     overcast clouds
# 18       14.97      US          few clouds
# 19        6.08      EC     overcast clouds
# 22       13.06      PF     overcast clouds
# 23        5.32      MV    scattered clouds
# 25        1.23      SB     overcast clouds
# 27        4.16      ID     overcast clouds
# 28        2.30      LK          few clouds
# 33       10.80      PH       broken clouds
# 34        4.61      BJ    scattered clouds
# 35        3.85      PG     overcast clouds
# 37        6.42      ML           clear sky
# 38        7.67      LR          light rain
# 39        8.93      IN     overcast clouds
# 41       18.41      BB          few clouds
# 42       12.66      AU           clear sky
# 43        7.54      AU           clear sky
# 48        8.55      PF     overcast clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 3          Matara      LK     82.20    scattered clouds   5.9485   80.5353
# 7   San Cristobal      VE     78.80                 fog   7.7669  -72.2250
# 8       Sinnamary      GF     77.86     overcast clouds   5.3833  -52.9500
# 18          Kapaa      US     78.80          few clouds  22.0752 -159.3190
# 19   Puerto Ayora      EC     75.60     overcast clouds  -0.7393  -90.3518
# 22        Rikitea      PF     78.71     overcast clouds -23.1203 -134.9692
# 23      Hithadhoo      MV     83.10    scattered clouds  -0.6000   73.0833
# 25       Kirakira      SB     81.68     overcast clouds -10.4544  161.9205
# 27      Samarinda      ID     87.48     overcast clouds  -0.5000  117.1500
# 28     Hambantota      LK     80.60          few clouds   6.1241   81.1185
#
#    Hotel Name
# 3
# 7
# 8
# 18
# 19
# 22
# 23
# 25
# 27
# 28

# %%
# %load_ext autoreload
# %autoreload
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    # 6c. Get latitude and longitude from DataFrame
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json" 

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json() 
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city. 
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
hotel_df["Hotel Name"]
hotel_df.head(15)
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#              City Country  Max Temp Current Description      Lat       Lng  \
# 3          Matara      LK     82.20    scattered clouds   5.9485   80.5353
# 7   San Cristobal      VE     78.80                 fog   7.7669  -72.2250
# 8       Sinnamary      GF     77.86     overcast clouds   5.3833  -52.9500
# 18          Kapaa      US     78.80          few clouds  22.0752 -159.3190
# 19   Puerto Ayora      EC     75.60     overcast clouds  -0.7393  -90.3518
# 22        Rikitea      PF     78.71     overcast clouds -23.1203 -134.9692
# 23      Hithadhoo      MV     83.10    scattered clouds  -0.6000   73.0833
# 25       Kirakira      SB     81.68     overcast clouds -10.4544  161.9205
# 27      Samarinda      ID     87.48     overcast clouds  -0.5000  117.1500
# 28     Hambantota      LK     80.60          few clouds   6.1241   81.1185
# 33          Basco      PH     76.33       broken clouds  20.4487  121.9702
# 34     Porto Novo      BJ     80.60    scattered clouds   6.4965    2.6036
# 35         Madang      PG     85.26     overcast clouds  -5.2246  145.7966
# 37          Kidal      ML     82.63           clear sky  18.4411    1.4078
# 38         Harper      LR     79.93          light rain   4.3750   -7.7169
#
#                                    Hotel Name
# 3                      Amaloh Boutique Resort
# 7                        Posada Villaven C.A.
# 8              ALETHEIA Appartement Sinnamary
# 18     Sheraton Kauai Resort at Coconut Beach
# 19                  Finch Bay Galapagos Hotel
# 22                             Pension Maro'i
# 23                          Scoop Guest House
# 25                               SanBiz Lodge
# 27  Aston Samarinda Hotel & Convention Center
# 28                                Bungalow 63
# 33                          Nathaniel's Lodge
# 34                    Tour Eiffel Hotel Benin
# 35                          Comfort Inn Hotel
# 37
# 38                                Screensaver

# %%
#count Null Values in Hotel_df 
hotel_df.shape
#hotel_df.info()
#hotel_df.isnull().sum()
# Out:
# (208, 7)

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df= clean_hotel_df[clean_hotel_df["Hotel Name"] != ""]
clean_hotel_df.info
# Out:
# <bound method DataFrame.info of                 City Country  Max Temp Current Description      Lat       Lng  \
# 3             Matara      LK     82.20    scattered clouds   5.9485   80.5353
# 7      San Cristobal      VE     78.80                 fog   7.7669  -72.2250
# 8          Sinnamary      GF     77.86     overcast clouds   5.3833  -52.9500
# 18             Kapaa      US     78.80          few clouds  22.0752 -159.3190
# 19      Puerto Ayora      EC     75.60     overcast clouds  -0.7393  -90.3518
# ..               ...     ...       ...                 ...      ...       ...
# 719             Beba      CU     78.80          few clouds  22.4437  -79.7253
# 723        Loa Janan      ID     87.33     overcast clouds  -0.5830  117.0950
# 725           Olinda      BR     75.20    scattered clouds  -8.0089  -34.8553
# 735      Corn Island      NI     80.65       broken clouds  12.1694  -83.0418
# 737  President Roxas      PH     89.60       broken clouds   7.1544  125.0558
#
#                                  Hotel Name
# 3                    Amaloh Boutique Resort
# 7                      Posada Villaven C.A.
# 8            ALETHEIA Appartement Sinnamary
# 18   Sheraton Kauai Resort at Coconut Beach
# 19                Finch Bay Galapagos Hotel
# ..                                      ...
# 719                       Hostal Cubaustria
# 723                         Pondok hijau 2A
# 725                Hotel Albergue de Olinda
# 735                    Big Fish Guest House
# 737                          Tiad Residence
#
# [200 rows x 7 columns]>

# %%
# 8a. Create the output File (CSV)
output_data_file = "../Vacation_Search/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.

info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
clean_hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]
print (clean_hotel_info)
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Amaloh Boutique Resort</dd>\n<dt>City</dt><dd>Matara</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>82.2 °F</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Posada Villaven C.A.</dd>\n<dt>City</dt><dd>San Cristobal</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n<dt>Current Weather</dt><dd>fog</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>ALETHEIA Appartement Sinnamary</dd>\n<dt>City</dt><dd>Sinnamary</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Max Temp</dt><dd>77.86 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Resort at Coconut Beach</dd>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Finch Bay Galapagos Hotel</dd>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>75.6 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n', "\n<dl>\n<dt>Hotel Name</dt><dd>Pension Maro'i</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.71 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n", '\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>83.1 °F</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>SanBiz Lodge</dd>\n<dt>City</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>81.68 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Aston Samarinda Hotel & Convention Center</dd>\n<dt>City</dt><dd>Samarinda</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>87.48 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Bungalow 63</dd>\n<dt>City</dt><dd>Hambantota</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n</dl>\n', "\n<dl>\n<dt>Hotel Name</dt><dd>Nathaniel's Lodge</dd>\n<dt>City</dt><dd>Basco</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>76.33 °F</dd>\n<dt>Current Weather</dt><dd>broken clouds</dd>\n</dl>\n", '\n<dl>\n<dt>Hotel Name</dt><dd>Tour Eiffel Hotel Benin</dd>\n<dt>City</dt><dd>Porto Novo</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n<dt>Current Weather</dt><dd>scattered clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Comfort Inn Hotel</dd>\n<dt>City</dt><dd>Madang</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>85.26 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Screensaver</dd>\n<dt>City</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Max Temp</dt><dd>79.93 °F</dd>\n<dt>Current Weather</dt><dd>light rain</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>residency of N.B vadhel</dd>\n<dt>City</dt><dd>Kodinar</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>87.49 °F</dd>\n<dt>Current Weather</dt><dd>overcast clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Atlantis Hotel</dd>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n<dt>Current Weather</dt><dd>few clouds</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>ibis Styles Mt Isa Verona</dd>\n<dt>City</dt><dd>Mount Isa</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>86.0 °F</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Blackwater Motor Inn</dd>\n<dt>City</dt><dd>Blackwater</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>80.89 °F</dd>\n<dt>Current Weather</dt><dd>clear sky</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Raiatea Lodge</dd>\n<dt>City</dt><dd>Tevaitoa</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt>< ...

# %%
# 11a. Add a marker layer for each city to the map. 
locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=clean_hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
